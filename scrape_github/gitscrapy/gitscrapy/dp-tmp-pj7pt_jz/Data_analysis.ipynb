# %%
import pickle 
import numpy as np 
import pandas as pd 
import datapane as dp 
import sweetviz

profile = pickle.load(open('profile_df', 'rb'))

profile
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-8525a2eb7ff6> in <module>
#       5 import sweetviz
#       6
# ----> 7 profile = pickle.load(open('profile_df', 'rb'))
#       8
#       9 profile
#
# FileNotFoundError: [Errno 2] No such file or directory: 'profile_df'

# %%
languges = list(set(profile.languages[0]))
languges = [language for language in languges if language != None]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5472acd44d1e> in <module>
# ----> 1 languges = list(set(profile.languages[0]))
#       2 languges = [language for language in languges if language != None]
#
# NameError: name 'profile' is not defined

# %%
languges
# Out:
# ['Python']

# %%
def process_languages(dup_languages):
    
    languages = None
    try:
        languages = list(set(dup_languages))
        languages = [language for language in languages if language != None]
    except:
        print(languages)
    
    return languages

# %%
def process_df(df):
    df.languages = df.languages.apply(process_languages)
    
    profile.followers = profile.followers.astype('int')

# %%
profile.languages = profile.languages.apply(process_languages)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
#Find percentage of missing values
profile.isnull().sum()/len(profile)
# Out:
# user_name       0.000000
# name            0.121528
# type_user       0.000000
# html_url        0.000000
# bio             0.523438
# company         0.486111
# email           0.568576
# followers       0.000000
# following       0.000000
# hireable        0.763021
# location        0.331597
# created_at      0.000000
# updated_at      0.000000
# total_stars     0.105035
# max_star        0.105035
# forks           0.105035
# languages       0.105035
# descriptions    0.105035
# dates           0.105035
# dtype: float64

# %% [markdown]
# # Visualization

# %%
import altair as alt 
import matplotlib.pyplot as plt
import numpy as np

# %%
list(profile.followers)
# Out:
# [2482,
#  4503,
#  0,
#  1187,
#  12647,
#  2775,
#  615,
#  2879,
#  1942,
#  4873,
#  0,
#  191,
#  0,
#  447,
#  2926,
#  1542,
#  45,
#  0,
#  2334,
#  1214,
#  0,
#  356,
#  0,
#  245,
#  0,
#  829,
#  387,
#  1081,
#  476,
#  3165,
#  0,
#  1259,
#  830,
#  36279,
#  535,
#  12647,
#  979,
#  3026,
#  5796,
#  990,
#  0,
#  491,
#  136,
#  1508,
#  5008,
#  0,
#  1685,
#  290,
#  208,
#  1111,
#  603,
#  0,
#  1468,
#  0,
#  8089,
#  419,
#  0,
#  310,
#  602,
#  285,
#  91,
#  233,
#  316,
#  119,
#  446,
#  362,
#  0,
#  0,
#  146,
#  0,
#  61,
#  446,
#  45,
#  0,
#  174,
#  523,
#  599,
#  73,
#  78,
#  657,
#  487,
#  544,
#  2834,
#  252,
#  381,
#  0,
#  0,
#  0,
#  0,
#  909,
#  41,
#  594,
#  2,
#  92,
#  55,
#  95,
#  44,
#  23,
#  11,
#  14,
#  114,
#  18,
#  41,
#  10,
#  50,
#  3,
#  27,
#  20,
#  30,
#  2153,
#  19,
#  7,
#  26,
#  36,
#  3,
#  29,
#  134,
#  196,
#  224,
#  55,
#  48,
#  59,
#  3,
#  309,
#  21,
#  23,
#  7,
#  48,
#  12,
#  38,
#  272,
#  12,
#  2,
#  127,
#  79,
#  38,
#  40,
#  3,
#  16,
#  33,
#  1,
#  2,
#  139,
#  0,
#  39,
#  664,
#  90,
#  120,
#  0,
#  138,
#  49,
#  6,
#  386,
#  3,
#  1,
#  19,
#  21,
#  35,
#  12,
#  4,
#  23,
#  7,
#  96,
#  11,
#  4,
#  353,
#  7,
#  861,
#  28,
#  80,
#  2018,
#  140,
#  0,
#  1630,
#  0,
#  399,
#  45,
#  75,
#  205,
#  2,
#  27,
#  32,
#  177,
#  26,
#  6,
#  43,
#  1,
#  11,
#  89,
#  357,
#  83,
#  1,
#  746,
#  25,
#  39,
#  24,
#  0,
#  4988,
#  206,
#  69,
#  3,
#  9068,
#  17,
#  43,
#  64,
#  46,
#  63,
#  4,
#  79,
#  25,
#  99,
#  18,
#  114,
#  280,
#  51,
#  4,
#  1,
#  41,
#  5,
#  8,
#  18,
#  0,
#  19,
#  125,
#  21,
#  69,
#  125,
#  25,
#  135,
#  11,
#  9,
#  107,
#  2,
#  2,
#  56,
#  0,
#  6,
#  3,
#  83,
#  23,
#  9,
#  4,
#  532,
#  70,
#  4,
#  40,
#  8,
#  6,
#  64,
#  23,
#  176,
#  11,
#  16,
#  763,
#  85,
#  98,
#  1285,
#  98,
#  3,
#  61,
#  1256,
#  0,
#  9,
#  69,
#  5,
#  566,
#  12,
#  40,
#  15,
#  102,
#  28,
#  0,
#  58,
#  11,
#  2,
#  111,
#  12,
#  88,
#  9,
#  11,
#  1943,
#  1354,
#  226,
#  22,
#  93,
#  3,
#  123,
#  0,
#  437,
#  29,
#  0,
#  11,
#  5,
#  9,
#  93,
#  67,
#  3,
#  96,
#  53,
#  125,
#  4,
#  6,
#  89,
#  9,
#  30,
#  53,
#  864,
#  16,
#  10,
#  0,
#  134,
#  2,
#  35,
#  198,
#  1518,
#  2,
#  16,
#  25,
#  1259,
#  0,
#  10,
#  0,
#  19,
#  82,
#  23,
#  5,
#  47,
#  1,
#  3,
#  118,
#  15,
#  38,
#  213,
#  22,
#  25,
#  49,
#  29,
#  14,
#  101,
#  23,
#  1,
#  50,
#  2,
#  60,
#  7,
#  4,
#  1223,
#  163,
#  24,
#  1735,
#  39,
#  0,
#  0,
#  33,
#  0,
#  14,
#  21,
#  81,
#  2,
#  78,
#  8,
#  149,
#  1,
#  131,
#  235,
#  62,
#  100,
#  7,
#  64,
#  1,
#  10,
#  1,
#  15,
#  3,
#  135,
#  44,
#  119,
#  66,
#  1,
#  12,
#  10,
#  12,
#  1,
#  28,
#  349,
#  9,
#  118,
#  26,
#  13,
#  7,
#  6,
#  27,
#  164,
#  13,
#  127,
#  5712,
#  2,
#  15,
#  469,
#  189,
#  160,
#  106,
#  4,
#  95,
#  26,
#  73,
#  3,
#  27,
#  20,
#  33,
#  260,
#  8,
#  18,
#  0,
#  32,
#  4,
#  32,
#  14,
#  0,
#  19,
#  3,
#  38,
#  8,
#  10,
#  541,
#  36,
#  16,
#  19,
#  6,
#  8,
#  8,
#  17,
#  1,
#  124,
#  28,
#  1,
#  6,
#  2,
#  461,
#  0,
#  2,
#  19,
#  98,
#  91,
#  47,
#  11,
#  3,
#  26,
#  1,
#  117,
#  6,
#  18,
#  4,
#  29,
#  11,
#  36,
#  44,
#  116,
#  530,
#  20,
#  9,
#  83,
#  453,
#  32,
#  25,
#  443,
#  24,
#  311,
#  180,
#  81,
#  12,
#  177,
#  54,
#  0,
#  3,
#  149,
#  13,
#  253,
#  26,
#  20,
#  32,
#  3,
#  1187,
#  35,
#  36,
#  5008,
#  30,
#  18,
#  118,
#  5,
#  57,
#  0,
#  7,
#  4,
#  5,
#  51,
#  26,
#  17,
#  59,
#  5,
#  1,
#  5,
#  1236,
#  1685,
#  0,
#  0,
#  33,
#  15,
#  84,
#  31,
#  38,
#  62,
#  32,
#  7,
#  175,
#  0,
#  12,
#  9,
#  7,
#  1410,
#  12647,
#  277,
#  63,
#  97,
#  30,
#  87,
#  132,
#  26,
#  14,
#  274,
#  0,
#  1,
#  8,
#  2,
#  119,
#  25,
#  29,
#  5,
#  188,
#  217,
#  808,
#  218,
#  2592,
#  19,
#  0,
#  0,
#  288,
#  680,
#  5,
#  73,
#  61,
#  26,
#  34,
#  1,
#  15,
#  55,
#  14,
#  9,
#  7,
#  4,
#  35,
#  38,
#  0,
#  11,
#  15,
#  16,
#  76,
#  241,
#  226,
#  83,
#  33,
#  16,
#  2,
#  19,
#  45,
#  30,
#  83,
#  96,
#  11,
#  1,
#  60,
#  15,
#  11,
#  1,
#  112,
#  314,
#  15,
#  90,
#  11,
#  0,
#  35,
#  23,
#  54,
#  20,
#  712,
#  3,
#  3,
#  11,
#  0,
#  1,
#  18,
#  26,
#  55,
#  7,
#  21,
#  34,
#  44,
#  1058,
#  16,
#  4,
#  203,
#  59,
#  380,
#  24,
#  11,
#  21,
#  255,
#  33,
#  4,
#  21,
#  11,
#  4,
#  15,
#  36,
#  41,
#  39,
#  147,
#  22,
#  24,
#  17,
#  38,
#  17,
#  0,
#  27,
#  60,
#  253,
#  36,
#  3056,
#  351,
#  3,
#  1185,
#  30,
#  2,
#  4,
#  11,
#  44,
#  14,
#  1665,
#  4,
#  54,
#  118,
#  3,
#  13,
#  30,
#  1,
#  12,
#  9,
#  107,
#  94,
#  5,
#  135,
#  6,
#  615,
#  2,
#  0,
#  1128,
#  2,
#  13,
#  0,
#  9,
#  53,
#  28,
#  6,
#  73,
#  0,
#  521,
#  14,
#  142,
#  542,
#  11,
#  17,
#  0,
#  9,
#  1,
#  353,
#  74,
#  0,
#  20,
#  26,
#  2,
#  25,
#  1,
#  19,
#  8093,
#  0,
#  2,
#  80,
#  115,
#  23,
#  8,
#  173,
#  33,
#  1,
#  48,
#  43,
#  23,
#  26,
#  362,
#  58,
#  3,
#  3,
#  8,
#  398,
#  6,
#  20,
#  46,
#  269,
#  74,
#  50,
#  24,
#  5,
#  17,
#  2,
#  13,
#  20,
#  1619,
#  12,
#  3,
#  37,
#  1326,
#  36,
#  59,
#  1014,
#  9690,
#  13,
#  807,
#  33,
#  49,
#  5,
#  14,
#  18,
#  15,
#  74,
#  60,
#  66,
#  5,
#  25,
#  27,
#  11,
#  9,
#  5,
#  155,
#  6,
#  37,
#  6,
#  62,
#  1,
#  75,
#  2,
#  11,
#  6,
#  0,
#  299,
#  15,
#  3,
#  116,
#  21,
#  42,
#  0,
#  8,
#  4,
#  1,
#  86,
#  40,
#  32,
#  169,
#  41,
#  6,
#  0,
#  0,
#  56,
#  253,
#  4,
#  80,
#  13,
#  11,
#  87,
#  42,
#  20,
#  26,
#  141,
#  4,
#  18,
#  49,
#  0,
#  246,
#  1,
#  305,
#  4,
#  45,
#  26,
#  252,
#  2,
#  27,
#  194,
#  21,
#  0,
#  0,
#  6,
#  340,
#  1,
#  19,
#  16,
#  1,
#  8,
#  46,
#  581,
#  9,
#  12315,
#  23,
#  1870,
#  2334,
#  195,
#  3,
#  6,
#  22,
#  1,
#  2,
#  66,
#  21,
#  8,
#  1,
#  15,
#  2,
#  6,
#  44,
#  6,
#  82,
#  4,
#  8,
#  21,
#  283,
#  1,
#  2,
#  18,
#  38,
#  23,
#  263,
#  2191,
#  151,
#  3,
#  23,
#  2,
#  0,
#  1,
#  56,
#  0,
#  8,
#  21,
#  786,
#  72,
#  78,
#  56,
#  259,
#  33,
#  53,
#  378,
#  370,
#  952,
#  471,
#  8,
#  488,
#  17,
#  2,
#  1148,
#  201,
#  3,
#  78,
#  31,
#  130,
#  5,
#  66,
#  13,
#  92,
#  12,
#  2,
#  45,
#  6,
#  3,
#  0,
#  92,
#  0,
#  135,
#  12,
#  120,
#  12,
#  3,
#  29,
#  12,
#  18,
#  12,
#  9,
#  26,
#  15,
#  4,
#  9,
#  232,
#  268,
#  435,
#  55,
#  61,
#  1,
#  0,
#  28,
#  126,
#  47,
#  20,
#  27,
#  423,
#  60,
#  48,
#  28,
#  2,
#  2,
#  46,
#  7,
#  7,
#  22,
#  1,
#  22,
#  7,
#  33,
#  173,
#  67,
#  656,
#  21,
#  27,
#  158,
#  5,
#  71,
#  29,
#  33,
#  152,
#  109,
#  522,
#  155,
#  92,
#  684,
#  907,
#  20,
#  20,
#  7,
#  751,
#  0,
#  4,
#  550,
#  0,
#  118,
#  2,
#  103,
#  0,
#  3,
#  19,
#  1,
#  30,
#  40,
#  284,
#  1,
#  0,
#  23,
#  114,
#  154,
#  52,
#  14,
#  2,
#  96,
#  292,
#  920,
#  51,
#  1,
#  591,
#  15,
#  5,
#  5675,
#  417,
#  31,
#  32,
#  3,
#  14,
#  200,
#  823,
#  4,
#  6,
#  0,
#  5,
#  59,
#  24,
#  5,
#  14,
#  33,
#  ...]

# %%
profile.user_name
# Out:
# 0       josephmisiti
# 1               wepe
# 2            udacity
# 3            ZuzooVn
# 4              rasbt
#             ...
# 1147        jimmysoa
# 1148          vizhur
# 1149       rdingwall
# 1150       xiaomaogy
# 1151    caleb-kaiser
# Name: user_name, Length: 1152, dtype: object

# %%
convert_dict = {'followers': int,
               'following':int,
               'hireable': bool,
               'total_stars': int,
               'max_star': int,
               'forks': int}

# %%
null_profile = profile[profile.max_star.isnull()]

# %%
dp.Report(dp.Table(null_profile))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-50fd42f4216c> in <module>
# ----> 1 dp.Report(dp.Table(null_profile))
#
# ~/anaconda3/envs/scraping/lib/python3.8/site-packages/datapane/client/api/report.py in __init__(self, df, **kwargs)
#      86 class Table(Asset):
#      87     def __init__(self, df: pd.DataFrame, **kwargs: JSON):
# ---> 88         fn = self._save_df(df)
#      89         super().__init__(file=fn.file, kwargs=kwargs)
#      90
#
# ~/anaconda3/envs/scraping/lib/python3.8/site-packages/datapane/client/api/dp_object.py in _save_df(cls, df, pivot)
#     201     def _save_df(cls, df: pd.DataFrame, pivot: bool = False) -> DPTmpFile:
#     202         ext = ".pvarrow" if pivot else ArrowFormat.ext
# --> 203         fn = DPTmpFile(ext)
#     204         df = to_df(df)
#     205         process_df(df)
#
# ~/anaconda3/envs/scraping/lib/python3.8/site-packages/datapane/client/api/common.py in __init__(self, ext)
#      39
#      40     def __init__(self, ext: str):
# ---> 41         fd, name = mkstemp(suffix=ext, prefix="dp-tmp-", dir=tmp_dir)
#      42         os.close(fd)
#      43         self.file = Path(name)
#
# ~/anaconda3/envs/scraping/lib/python3.8/tempfile.py in mkstemp(suffix, prefix, dir, text)
#     330         flags = _bin_openflags
#     331
# --> 332     return _mkstemp_inner(dir, prefix, suffix, flags, output_type)
#     333
#     334
#
# ~/anaconda3/envs/scraping/lib/python3.8/tempfile.py in _mkstemp_inner(dir, pre, suf, flags, output_type)
#     248         _sys.audit("tempfile.mkstemp", file)
#     249         try:
# --> 250             fd = _os.open(file, flags, 0o600)
#     251         except FileExistsError:
#     252             continue    # try again
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/khuyentran/EPS-Y/scrape_github/gitscrapy/gitscrapy/spiders/dp-tmp-1fmd884z/dp-tmp-n4nh8uee.arrow'

# %%
profile.astype(convert_dict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-7e72ca3c46ec> in <module>
# ----> 1 profile.astype(convert_dict)
#
# ~/anaconda3/envs/scraping/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5681                 if col_name in dtype:
#    5682                     results.append(
# -> 5683                         col.astype(dtype=dtype[col_name], copy=copy, errors=errors)
#    5684                     )
#    5685                 else:
#
# ~/anaconda3/envs/scraping/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~/anaconda3/envs/scraping/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ~/anaconda3/envs/scraping/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# ~/anaconda3/envs/scraping/lib/python3.8/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     623             vals1d = values.ravel()
#     624             try:
# --> 625                 values = astype_nansafe(vals1d, dtype, copy=True)
#     626             except (ValueError, TypeError):
#     627                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~/anaconda3/envs/scraping/lib/python3.8/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     872         # work around NumPy brokenness, #1987
#     873         if np.issubdtype(dtype.type, np.integer):
# --> 874             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     875
#     876         # if we have a datetime/timedelta array of objects
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'NoneType'

# %%
profile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1152 entries, 0 to 1151
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   user_name     1152 non-null   object
#  1   name          1012 non-null   object
#  2   type_user     1152 non-null   object
#  3   html_url      1152 non-null   object
#  4   bio           549 non-null    object
#  5   company       592 non-null    object
#  6   email         497 non-null    object
#  7   followers     1152 non-null   object
#  8   following     1152 non-null   object
#  9   hireable      273 non-null    object
#  10  location      770 non-null    object
#  11  created_at    1152 non-null   datetime64[ns]
#  12  updated_at    1152 non-null   datetime64[ns]
#  13  total_stars   1031 non-null   object
#  14  max_star      1031 non-null   object
#  15  forks         1031 non-null   object
#  16  languages     1031 non-null   object
#  17  descriptions  1031 non-null   object
#  18  dates         1031 non-null   object
# dtypes: datetime64[ns](2), object(17)
# memory usage: 171.1+ KB

# %%
profile.hireable.unique()

# %%
plt.bar(np.arange(len(profile)), list(profile.followers))

# %%
alt.Chart(profile).mark_line().encode(
    x='folowers',
)
